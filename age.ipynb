# %%
drugs_age_map = {
    -0.95197: "18-24",
    -0.07854: "25-34",
    0.49788: "35-44",
    1.09449: "45-54",
    1.82213: "55-64",
    2.59171: "65+"
}

drugs_df['age_cat'] = drugs_df['age'].map(drugs_age_map)

# %%
drugs_gender_map = {
    0.48246: "Female",
    -0.48246: "Male"
}

drugs_df['gender_cat'] = drugs_df['gender'].map(drugs_gender_map)

# %%
drugs_ethnicity_map = {
    -0.50212: "Asian",
    -1.10702: "Black",
    1.90725: "Mixed-Black/Asian",
    0.12600: "Mixed-White/Asian",
    -0.22166: "Mixed-White/Black",
    0.11440: "Other", 
    -0.31685: "White"
}

drugs_df['ethnicity_cat'] = drugs_df['ethnicity'].map(drugs_ethnicity_map)
